# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('C:/Users/FRIDAY/Documents/Valve_Player_Data.csv')

# %%
df.head()
# Out:
#        Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0  September 2021    512350.92     268.96       +0.05%        942519
# 1     August 2021    512081.96    6014.60       +1.19%        802544
# 2       July 2021    506067.36  -43279.72       -7.88%        763523
# 3       June 2021    549347.08 -110541.81      -16.75%        929940
# 4        May 2021    659888.89  -63457.63       -8.77%       1087197
#
#                                URL        Date  \
# 0  https://steamcharts.com/app/730  2021-09-01
# 1  https://steamcharts.com/app/730  2021-08-01
# 2  https://steamcharts.com/app/730  2021-07-01
# 3  https://steamcharts.com/app/730  2021-06-01
# 4  https://steamcharts.com/app/730  2021-05-01
#
#                           Game_Name
# 0  Counter Strike: Global Offensive
# 1  Counter Strike: Global Offensive
# 2  Counter Strike: Global Offensive
# 3  Counter Strike: Global Offensive
# 4  Counter Strike: Global Offensive

# %%
df.tail()
# Out:
#           Month_Year  Avg_players    Gain Percent_Gain  Peak_Players  \
# 5266   December 2016       192.03  -21.90      -10.24%           405
# 5267   November 2016       213.92 -134.68      -38.63%           537
# 5268    October 2016       348.60 -201.75      -36.66%          1031
# 5269  September 2016       550.36  543.26    +7654.89%          2836
# 5270     August 2016         7.10     NaN          NaN            18
#
#                                      URL        Date                 Game_Name
# 5266  https://steamcharts.com/app/435150  2016-12-01  Divinity: Original Sin 2
# 5267  https://steamcharts.com/app/435150  2016-11-01  Divinity: Original Sin 2
# 5268  https://steamcharts.com/app/435150  2016-10-01  Divinity: Original Sin 2
# 5269  https://steamcharts.com/app/435150  2016-09-01  Divinity: Original Sin 2
# 5270  https://steamcharts.com/app/435150  2016-08-01  Divinity: Original Sin 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5271 entries, 0 to 5270
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Month_Year    5271 non-null   object
#  1   Avg_players   5271 non-null   float64
#  2   Gain          5173 non-null   float64
#  3   Percent_Gain  5173 non-null   object
#  4   Peak_Players  5271 non-null   int64
#  5   URL           5271 non-null   object
#  6   Date          5271 non-null   object
#  7   Game_Name     5271 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 329.6+ KB

# %%
df.shape
# Out:
# (5271, 8)

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5266    False
# 5267    False
# 5268    False
# 5269    False
# 5270    False
# Length: 5271, dtype: bool

# %%
df.loc[5270,'GAME_NAME']=5271

# %%
df.tail()
# Out:
#           Month_Year  Avg_players    Gain Percent_Gain  Peak_Players  \
# 5266   December 2016       192.03  -21.90      -10.24%           405
# 5267   November 2016       213.92 -134.68      -38.63%           537
# 5268    October 2016       348.60 -201.75      -36.66%          1031
# 5269  September 2016       550.36  543.26    +7654.89%          2836
# 5270     August 2016         7.10     NaN          NaN            18
#
#                                      URL        Date  \
# 5266  https://steamcharts.com/app/435150  2016-12-01
# 5267  https://steamcharts.com/app/435150  2016-11-01
# 5268  https://steamcharts.com/app/435150  2016-10-01
# 5269  https://steamcharts.com/app/435150  2016-09-01
# 5270  https://steamcharts.com/app/435150  2016-08-01
#
#                      Game_Name  GAME_NAME
# 5266  Divinity: Original Sin 2        NaN
# 5267  Divinity: Original Sin 2        NaN
# 5268  Divinity: Original Sin 2        NaN
# 5269  Divinity: Original Sin 2        NaN
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [Month_Year, Avg_players, Gain, Percent_Gain, Peak_Players, URL, Date, Game_Name, GAME_NAME]
# Index: []

# %%
df.head()
# Out:
#        Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0  September 2021    512350.92     268.96       +0.05%        942519
# 1     August 2021    512081.96    6014.60       +1.19%        802544
# 2       July 2021    506067.36  -43279.72       -7.88%        763523
# 3       June 2021    549347.08 -110541.81      -16.75%        929940
# 4        May 2021    659888.89  -63457.63       -8.77%       1087197
#
#                                URL        Date  \
# 0  https://steamcharts.com/app/730  2021-09-01
# 1  https://steamcharts.com/app/730  2021-08-01
# 2  https://steamcharts.com/app/730  2021-07-01
# 3  https://steamcharts.com/app/730  2021-06-01
# 4  https://steamcharts.com/app/730  2021-05-01
#
#                           Game_Name  GAME_NAME
# 0  Counter Strike: Global Offensive        NaN
# 1  Counter Strike: Global Offensive        NaN
# 2  Counter Strike: Global Offensive        NaN
# 3  Counter Strike: Global Offensive        NaN
# ...

# %%
for x in df.index:
    if df.loc[x,'GAME_NAME']:
        df.drop(x,inplace=True)
print(df.to_string())
# Out:
# Empty DataFrame
# Columns: [Month_Year, Avg_players, Gain, Percent_Gain, Peak_Players, URL, Date, Game_Name, GAME_NAME]
# Index: []

# %%
pd.DataFrame(df)
# Out:
# Empty DataFrame
# Columns: [Month_Year, Avg_players, Gain, Percent_Gain, Peak_Players, URL, Date, Game_Name, GAME_NAME]
# Index: []

# %%
df.head()
# Out:
# Empty DataFrame
# Columns: [Month_Year, Avg_players, Gain, Percent_Gain, Peak_Players, URL, Date, Game_Name, GAME_NAME]
# Index: []

# %%
df=pd.read_csv('E:/software/archive (1)/Valve_Player_Data.csv')

# %%
df.head()
# Out:
#        Month_Year  Avg_players       Gain Percent_Gain  Peak_Players  \
# 0  September 2021    512350.92     268.96       +0.05%        942519
# 1     August 2021    512081.96    6014.60       +1.19%        802544
# 2       July 2021    506067.36  -43279.72       -7.88%        763523
# 3       June 2021    549347.08 -110541.81      -16.75%        929940
# 4        May 2021    659888.89  -63457.63       -8.77%       1087197
#
#                                URL        Date  \
# 0  https://steamcharts.com/app/730  2021-09-01
# 1  https://steamcharts.com/app/730  2021-08-01
# 2  https://steamcharts.com/app/730  2021-07-01
# 3  https://steamcharts.com/app/730  2021-06-01
# 4  https://steamcharts.com/app/730  2021-05-01
#
#                           Game_Name
# 0  Counter Strike: Global Offensive
# 1  Counter Strike: Global Offensive
# 2  Counter Strike: Global Offensive
# 3  Counter Strike: Global Offensive
# 4  Counter Strike: Global Offensive

# %%
df.loc[5270,'GAME_NAME']=5271

# %%
df.tail()
# Out:
#           Month_Year  Avg_players    Gain Percent_Gain  Peak_Players  \
# 5266   December 2016       192.03  -21.90      -10.24%           405
# 5267   November 2016       213.92 -134.68      -38.63%           537
# 5268    October 2016       348.60 -201.75      -36.66%          1031
# 5269  September 2016       550.36  543.26    +7654.89%          2836
# 5270     August 2016         7.10     NaN          NaN            18
#
#                                      URL        Date  \
# 5266  https://steamcharts.com/app/435150  2016-12-01
# 5267  https://steamcharts.com/app/435150  2016-11-01
# 5268  https://steamcharts.com/app/435150  2016-10-01
# 5269  https://steamcharts.com/app/435150  2016-09-01
# 5270  https://steamcharts.com/app/435150  2016-08-01
#
#                      Game_Name  GAME_NAME
# 5266  Divinity: Original Sin 2        NaN
# 5267  Divinity: Original Sin 2        NaN
# 5268  Divinity: Original Sin 2        NaN
# 5269  Divinity: Original Sin 2        NaN
# ...

# %%
del df['GAME_NAME']

# %%
df.tail()
# Out:
#           Month_Year  Avg_players    Gain Percent_Gain  Peak_Players  \
# 5266   December 2016       192.03  -21.90      -10.24%           405
# 5267   November 2016       213.92 -134.68      -38.63%           537
# 5268    October 2016       348.60 -201.75      -36.66%          1031
# 5269  September 2016       550.36  543.26    +7654.89%          2836
# 5270     August 2016         7.10     NaN          NaN            18
#
#                                      URL        Date                 Game_Name
# 5266  https://steamcharts.com/app/435150  2016-12-01  Divinity: Original Sin 2
# 5267  https://steamcharts.com/app/435150  2016-11-01  Divinity: Original Sin 2
# 5268  https://steamcharts.com/app/435150  2016-10-01  Divinity: Original Sin 2
# 5269  https://steamcharts.com/app/435150  2016-09-01  Divinity: Original Sin 2
# 5270  https://steamcharts.com/app/435150  2016-08-01  Divinity: Original Sin 2
